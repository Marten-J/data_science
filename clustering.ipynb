# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
plt.rcParams['figure.figsize'] = (16, 9)

# Loading csv
url = 'https://drive.google.com/uc?export=download&id=1sTO90PQRtbK80XdzMJ2KttRRtt9M7xuq'
df = pd.read_csv(url)

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(df.V1, df.V2, df.V3)

# %%
# Initializing KMeans
kmeans = KMeans(n_clusters=5)
# Fitting with inputs
kmeans = kmeans.fit(df)
# Predicting the clusters
labels = kmeans.predict(df)
# Getting the cluster centers
C = kmeans.cluster_centers_

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(df.V1, df.V2, df.V3)
ax.scatter(C[:, 0], C[:, 1], C[:, 2], marker='*', c='#050505', s=1000)

# %%
i = 0
clusters = ""
for label in kmeans.labels_:
    clusters += "point i=" + str(i) + " belongs to cluster " + str(label) + ", "
    if (i % 3 == 0):
        clusters += "\n"
    i += 1
    
print(clusters)
# Out:
# point i=0 belongs to cluster 2,
# point i=1 belongs to cluster 3, point i=2 belongs to cluster 3, point i=3 belongs to cluster 0,
# point i=4 belongs to cluster 3, point i=5 belongs to cluster 4, point i=6 belongs to cluster 0,
# point i=7 belongs to cluster 3, point i=8 belongs to cluster 1, point i=9 belongs to cluster 0,
# point i=10 belongs to cluster 3, point i=11 belongs to cluster 1, point i=12 belongs to cluster 0,
# point i=13 belongs to cluster 4, point i=14 belongs to cluster 2, point i=15 belongs to cluster 3,
# point i=16 belongs to cluster 1, point i=17 belongs to cluster 4, point i=18 belongs to cluster 2,
# point i=19 belongs to cluster 2, point i=20 belongs to cluster 3, point i=21 belongs to cluster 1,
# point i=22 belongs to cluster 2, point i=23 belongs to cluster 3, point i=24 belongs to cluster 3,
# point i=25 belongs to cluster 0, point i=26 belongs to cluster 1, point i=27 belongs to cluster 1,
# point i=28 belongs to cluster 1, point i=29 belongs to cluster 4, point i=30 belongs to cluster 1,
# point i=31 belongs to cluster 1, point i=32 belongs to cluster 4, point i=33 belongs to cluster 4,
# point i=34 belongs to cluster 3, point i=35 belongs to cluster 2, point i=36 belongs to cluster 4,
# point i=37 belongs to cluster 2, point i=38 belongs to cluster 1, point i=39 belongs to cluster 3,
# point i=40 belongs to cluster 4, point i=41 belongs to cluster 4, point i=42 belongs to cluster 4,
# point i=43 belongs to cluster 2, point i=44 belongs to cluster 4, point i=45 belongs to cluster 3,
# point i=46 belongs to cluster 0, point i=47 belongs to cluster 0, point i=48 belongs to cluster 4,
# point i=49 belongs to cluster 0, point i=50 belongs to cluster 0, point i=51 belongs to cluster 4,
# point i=52 belongs to cluster 1, point i=53 belongs to cluster 1, point i=54 belongs to cluster 0,
# point i=55 belongs to cluster 0, point i=56 belongs to cluster 2, point i=57 belongs to cluster 0,
# point i=58 belongs to cluster 3, point i=59 belongs to cluster 4, point i=60 belongs to cluster 0,
# point i=61 belongs to cluster 2, point i=62 belongs to cluster 0, point i=63 belongs to cluster 0,
# point i=64 belongs to cluster 4, point i=65 belongs to cluster 0, point i=66 belongs to cluster 2,
# point i=67 belongs to cluster 2, point i=68 belongs to cluster 2, point i=69 belongs to cluster 4,
# point i=70 belongs to cluster 4, point i=71 belongs to cluster 0, point i=72 belongs to cluster 1,
# point i=73 belongs to cluster 0, point i=74 belongs to cluster 0, point i=75 belongs to cluster 1,
# point i=76 belongs to cluster 3, point i=77 belongs to cluster 4, point i=78 belongs to cluster 0,
# point i=79 belongs to cluster 1, point i=80 belongs to cluster 1, point i=81 belongs to cluster 4,
# point i=82 belongs to cluster 3, point i=83 belongs to cluster 2, point i=84 belongs to cluster 2,
# point i=85 belongs to cluster 3, point i=86 belongs to cluster 2, point i=87 belongs to cluster 2,
# point i=88 belongs to cluster 2, point i=89 belongs to cluster 0, point i=90 belongs to cluster 1,
# point i=91 belongs to cluster 1, point i=92 belongs to cluster 1, point i=93 belongs to cluster 3,
# point i=94 belongs to cluster 0, point i=95 belongs to cluster 0, point i=96 belongs to cluster 1,
# point i=97 belongs to cluster 4, point i=98 belongs to cluster 2, point i=99 belongs to cluster 2,
